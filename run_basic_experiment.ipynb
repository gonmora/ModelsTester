# %%
import os
from src.runner.engine import run_loop, WeightStore

DF_NAME = "BTCUSDT_5m_20100101_20250814"

os.environ["WEIGHTS_JSON"] = "data/weights_BIG.json" # calificaciones separadas
DB_PATH = "runs_BIG.db" # historial separado

os.environ["DATA_DIR"] = "data_big"
ws = WeightStore(path=os.environ["WEIGHTS_JSON"])
#while True:
#    try:
run_ids = run_loop(df_name=DF_NAME, split_id="default", n_runs=500, seed=42, db_path=DB_PATH, weight_store=ws)
#except Exception as e:
#        print(e)
# Out:
# 2025-08-29 07:41:55.279471: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-08-29 07:41:55.545020: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-08-29 07:41:55.632513: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...
